# %%
# %cd /home/luke-padmore/Source/flow-matching-mnist
# Out:
# /home/luke-padmore/Source/flow-matching-mnist

# %%
import torchvision
import mlflow
import math
import torch
import matplotlib.pyplot as plt 
import torch.nn as nn 
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from models.unet import UNet
from functools import partial
import os, sys
from models.ode_solvers import euler_solver, rk2_solver, make_vf_uncond,create_samples
from pathlib import Path 

# For system metrics
os.environ["MLFLOW_ENABLE_SYSTEM_METRICS_LOGGING"] = "true"
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

batch_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Pad(2,padding_mode='constant'),
    transforms.Normalize((0.5,), (0.5,))]
)
trainset = torchvision.datasets.MNIST(root = '/home/luke-padmore/Source/flow-matching-mnist/data',
                                      train=True,
                                      download=True,
                                      transform=transform)
trainloader = DataLoader(trainset,
                        batch_size=batch_size,
                        shuffle=True,
                        num_workers=4)
valset = torchvision.datasets.MNIST(root = '/home/luke-padmore/Source/flow-matching-mnist/data',
                                      train=False,
                                      download=True,
                                      transform=transform)
valloader = DataLoader(valset,
                        batch_size=batch_size,
                        shuffle=True,
                        num_workers=4)

# %%
run_id = "4435f756670844fbbc1a89bff37cba34"
model = mlflow.pytorch.load_model(f"runs:/{run_id}/UNet")
print(model)
# Out:
# /home/luke-padmore/miniconda3/envs/ml/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 6/6 [00:00<00:00, 314.92it/s]
# UNet(
#   (encoder): Encoder(
#     (initial_conv): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (down_blocks): ModuleList(
#       (0): ConvDownblock(
#         (conv): Sequential(
#           (0): GroupNorm(8, 40, eps=1e-05, affine=True)
#           (1): Conv2d(40, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (down): Sequential(
#           (0): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (2): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#       (1): ConvDownblock(
#         (conv): Sequential(
#           (0): GroupNorm(8, 40, eps=1e-05, affine=True)
#           (1): Conv2d(40, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (down): Sequential(
#           (0): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (2): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#       (2): ConvDownblock(
#         (conv): Sequential(
#           (0): GroupNorm(8, 72, eps=1e-05, affine=True)
#           (1): Conv2d(72, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (down): Sequential(
#           (0): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (2): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#     )
#   )
#   (decoder): Decoder(
#     (up_blocks): ModuleList(
#       (0): ConvUpblock(
#         (upsampler): Upsample(scale_factor=2.0, mode='nearest')
#         (block): Sequential(
#           (0): GroupNorm(8, 264, eps=1e-05, affine=True)
#           (1): Conv2d(264, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#       (1): ConvUpblock(
#         (upsampler): Upsample(scale_factor=2.0, mode='nearest')
#         (block): Sequential(
#           (0): GroupNorm(8, 136, eps=1e-05, affine=True)
#           (1): Conv2d(136, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#       (2): ConvUpblock(
#         (upsampler): Upsample(scale_factor=2.0, mode='nearest')
#         (block): Sequential(
#           (0): GroupNorm(8, 72, eps=1e-05, affine=True)
#           (1): Conv2d(72, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2): SiLU()
#           (3): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): SiLU()
#         )
#         (time_emb_mlp): Linear(in_features=8, out_features=8, bias=True)
#       )
#     )
#     (final_conv): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (bottleneck): Bottleneck(
#     (bottleneck): Sequential(
#       (0): GroupNorm(8, 144, eps=1e-05, affine=True)
#       (1): Conv2d(144, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): SiLU()
#       (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (5): SiLU()
#     )
#     (time_emb_mlp): Linear(in_features=8, out_features=16, bias=False)
#   )
#   (time_embedding_mlp): SinusoidalTimeEmbedding(
#     (mlp): Sequential(
#       (0): Linear(in_features=128, out_features=8, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#     )
#   )
# )

# %%
from models.ode_solvers import get_ode_solver_from_name
from utils.mlflow_tracking_utils import get_run_param, parse_int_list
ode_solver = get_ode_solver_from_name(get_run_param(run_id,"ode_solver"))
image_shape = parse_int_list(get_run_param(run_id,"image_shape"))
ode_steps = int(get_run_param(run_id,"ode_steps"))
batch_size = int(get_run_param(run_id,"batch_size"))
 
f = make_vf_uncond(model)

sample_fn = partial(
    create_samples,
    image_shape= image_shape,
    ode_solver = ode_solver,
    f=f,
    n_steps=ode_steps,
    seed=None,
    device=device,
)
sample_fn
# Out:
# functools.partial(<function create_samples at 0x73a4fc0fdf80>, image_shape=(1, 32, 32), ode_solver=<function euler_solver at 0x73a4fc0fdbc0>, f=<function make_vf_uncond.<locals>.f at 0x73a4f7b65940>, n_steps=50, seed=None, device=device(type='cuda', index=0))

# %%
from evalutate_fid_uncond import run_eval
import numpy as np

fid, gen_embs, real_embs = run_eval(
    run_id,
    n_samples=64000,
)

print("FID:", fid)
print("gen_embs:", None if gen_embs is None else gen_embs.shape)
print("real_embs:", None if real_embs is None else real_embs.shape)

np.savez("notebooks/fid_exports/generated_embeddings.npz", embs=gen_embs)
np.savez("notebooks/fid_exports/real_embeddings.npz", embs=real_embs)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 6/6 [00:00<00:00, 1214.10it/s]
# 2026/03/05 22:45:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# /home/luke-padmore/miniconda3/envs/ml/lib/python3.12/site-packages/mlflow/tracking/_model_registry/utils.py:216: FutureWarning: The filesystem model registry backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri)
# 2026/03/05 22:45:35 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/03/05 22:45:35 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 from evalutate_fid_uncond import run_eval
#       2 import numpy as np
# ----> 4 fid, gen_embs, real_embs = run_eval(
#       5     run_id,
#       6     n_samples=64000,
#       7 )
#       9 print("FID:", fid)
#      10 print("gen_embs:", None if gen_embs is None else gen_embs.shape)
#
# File ~/Source/flow-matching-mnist/evalutate_fid_uncond.py:52, in run_eval(generator_run_id, generator_name, backbone_uri, stats_filename, real_embeddings_filename, n_samples, device, seed, export_path, real_loader)
#      49 mlflow.set_experiment("FM-uncond-eval")
#      50 with mlflow.start_run(run_name = run_name):
# ---> 52     fid, gen_embs, real_embs = evaluate_fid_with_registered_backbone(
#      53         sample_fn = sample_fn,
#      54         device = device,
#      55         backbone_uri=backbone_uri,
#      56         stats_filename=stats_filename,
#      57         real_embeddings_filename=real_embeddings_filename,
#      58         n_samples = n_samples,
#      59         batch_size=batch_size,
#      60         real_loader=real_loader,
#      61     )
#      62     mlflow.log_metric("fid", float(fid))
#      63     mlflow.log_params({
#      64         "fid_backbone_uri": backbone_uri,
#      65         "fid_n_samples": n_samples,
#    (...)     68         "seed": seed
#      69     })
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Source/flow-matching-mnist/utils/FID/fid_evaluation.py:113, in evaluate_fid_with_registered_backbone(sample_fn, device, backbone_uri, stats_filename, real_embeddings_filename, n_samples, batch_size, real_loader)
#     111 while remaining > 0:
#     112     b = min(batch_size, remaining)
# --> 113     imgs = sample_fn(b)
#     114     if not torch.is_tensor(imgs):
#     115         raise TypeError("sample_fn must return a torch.Tensor")
#
# File ~/Source/flow-matching-mnist/models/ode_solvers.py:101, in create_samples(n_images, image_shape, ode_solver, f, n_steps, return_all, device, seed, clamp_mode, clamp_range)
#      98     g = torch.Generator(device=device).manual_seed(seed)
#     100 x0 = torch.randn((n_images, *image_shape), device=device, generator=g)
# --> 101 xs,_ = ode_solver(f, x0, 0.0, 1.0, n_steps)
#     103 # Apply clamping/squashing to each step
#     104 if clamp_mode == "clamp":
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Source/flow-matching-mnist/models/ode_solvers.py:16, in euler_solver(f, x0, t0, t1, n_steps)
#      14     xs.append(x.clone())
#      15     if k < n_steps:
# ---> 16         dx = f(x, t)
#      17         x = x + h * dx
#      18 return xs, ts
#
# File ~/Source/flow-matching-mnist/models/ode_solvers.py:44, in make_vf_uncond.<locals>.f(x, t_scalar)
#      42 def f(x, t_scalar: float):
#      43     t = torch.full((x.size(0), 1, 1, 1), t_scalar, device=x.device, dtype=x.dtype)
# ---> 44     return model(x, t)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Source/flow-matching-mnist/models/unet.py:419, in UNet.forward(self, x, t, *args, **kwargs)
#     417 x, skip_features = self.encoder(x, time_emb)
#     418 x = self.bottleneck(x, time_emb)
# --> 419 x = self.decoder(x, time_emb, skip_features)
#     420 return x
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Source/flow-matching-mnist/models/unet.py:321, in Decoder.forward(self, x, time_emb, skip_features)
#     317 def forward(
#     318     self, x, time_emb: torch.Tensor, skip_features: list[torch.Tensor]
#     319 ) -> torch.Tensor:
#     320     for block in self.up_blocks:
# --> 321         x = block(x, time_emb, skip_features.pop())
#     322     return self.final_conv(x)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Source/flow-matching-mnist/models/unet.py:222, in ConvUpblock.forward(self, x, time_emb, skip_features)
#     220 x = torch.cat([x, skip_features, time_emb], dim=1)
#     221 # Pass through block
# --> 222 return self.conv(x)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/torch/nn/modules/module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'ConvUpblock' object has no attribute 'conv'
